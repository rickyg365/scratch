# %% [markdown]
# Dataset Notes:
#
# Locations:
# hulu: hulu/hulu_titles.csv
#
# columns:
# hulu -> [show_id, type(Movie or TV Show), title, director, cast, country, date_added, release_year, rating, duration(min), listed_in, description]

# %%
import pandas as pd

# %%
filepath = "hulu/hulu_titles.csv"
# set header to none if there are no column names on the first line just the first entry
hulu_movie_data = pd.read_csv(filepath)

# %%
# To get all column titles
# hulu_movie_data.columns

# more details for numerical (mean, min, max)
# hulu_movie_data.describe()

hulu_movie_data
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
# drop columns, axis=0 (row) | axis=1 (col)
movie_no_director = hulu_movie_data.drop(labels='director', axis=1)
movie_titles = hulu_movie_data["title"]

movie_titles
# Out:
# 0       Ricky Velez: Here's Everything
# 1                         Silent Night
# 2                         The Marksman
# 3                                 Gaia
# 4                             Settlers
#                      ...
# 3068    Star Trek: The Original Series
# 3069                Star Trek: Voyager
# 3070                         The Fades
# 3071                 The Twilight Zone
# 3072               Tokyo Magnitude 8.0
# Name: title, Length: 3073, dtype: object
